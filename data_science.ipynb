# %%
budget=int(input("Enter your budget:"))
mobile=30000
if budget>=mobile:
    print("You can buy the mobile")
else:
    print("You cannot buy the mobile")
# Out:
# Enter your budget:40000
# You can buy the mobile

# %%
storage=int(input("Enter the storage:"))
if storage==32:
    print("15000")
elif storage==64:
    print(20000)
elif storage==128:
    print(30000)
elif storage==256:
    print(40000)
else:
    print("NA")
# Out:
# Enter the storage:40000
# NA

# %%
a=60
b=13
print(a & b)
print(a|b)
print(a^b)
print(~a)
print(~b)
# Out:
# 12
# 61
# 49
# -61
# -14

# %%
round1=int(input("Enter your round 1 marks:"))
if round1>=80:
    print("You are eligible for second round")
else:
    print("You failed")
    exit(1)
round2=int(input("Enter your round 2 marks:"))
if round2>=70:
    print("You are eligible for third round")
else:
    print("You failed")
    exit(1)
round3=int(input("Enter your round 3 marks:"))
if round3>=60:
    print("You are SELECTED")
else:
    print("You are REJECTED")
# Out:
# Enter your round 1 marks:90
# You are eligible for second round
# Enter your round 2 marks:50
# You failed
# Enter your round 3 marks:60
# You are SELECTED

# %%
def student_group(marks):
    if marks >= 80:
        return "Group1"
    elif 60 <= marks < 80:
        return "Group2"
    elif 40 <= marks < 60:
        return "Group3"
    else:
        return "No Group"

# Example usage
marks = int(input("Enter student marks: "))
print("Student belongs to:", student_group(marks))
# Out:
# Enter student marks: 70
# Student belongs to: Group2

# %%
# Nested Login System
username = input("Enter username: ")

if username == "admin":
    password = input("Enter password: ")

    if password == "12345":
        print("Login successful")
    else:
        print("Incorrect password")
else:
    print("Incorrect username")
